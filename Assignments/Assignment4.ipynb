# %% [markdown]
# Task 1: Read a File and Handle Errors
# Problem Statement:  Write a Python program that:
# 1.   Opens and reads a text file named sample.txt.
# 2.   Prints its content line by line.
# 3.   Handles errors gracefully if the file does not exist.

# %%
try:
    with open("sample.txt", "r") as file:
        print("File opened successfully. Contents are:\n")
        for line in file:
            print(line, end="")   # prints line by line without extra spacing

except FileNotFoundError:
    print("Error: sample.txt not found!")
    print("Please create the file and try again.")
# Out:
# Error: sample.txt not found!
# Please create the file and try again.

# %% [markdown]
# Task 2: Write and Append Data to a File
#
# Problem Statement: Write a Python program that:
# 1.   Takes user input and writes it to a file named output.txt.
# 2.   Appends additional data to the same file.
# 3.   Reads and displays the final content of the file.

# %%
t
data = input("Enter some text to store in file: ")

# Step 1 – Write to the file
with open("output.txt", "w") as file:
    file.write(data + "\n")

# Step 2 – Append additional content
with open("output.txt", "a") as file:
    file.write("This is appended content.\n")

# Step 3 – Read and display final content
with open("output.txt", "r") as file:
    print("\nFinal file content:\n")
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 t
#       2 data = input("Enter some text to store in file: ")
#       4 # Step 1 – Write to the file
#
# NameError: name 't' is not defined
